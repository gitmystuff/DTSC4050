# %% [markdown]
# <a href="https://colab.research.google.com/github/gitmystuff/DTSC4050/blob/main/04-Probability/04_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 04 - Assignment
#
# Your Name

# %% [markdown]
# ## Getting Started
#
# * Colab - get notebook from gitmystuff DTSC4050 repository
# * Save a Copy in Drive
# * Remove Copy of
# * Edit name
# * Clean up Colab Notebooks folder
# * Submit shared link

# %% [markdown]
# **Instructions:**  Here are 20 dataset examples, each with 3-5 rows, designed to help us practice distinguishing between Exploratory Data Analysis (EDA), Linear Regression, and Logistic Regression scenarios.  Remember, the key is the *type* of dependent variable (or lack thereof).
#
# For each dataset, double click on the Answer Text Cell and then decide whether the data is best suited for EDA, Linear Regression, or Logistic Regression, and briefly explain why.

# %% [markdown]
# 1. **Coffee Shop Sales:**
#
# | Daily Customers | Avg Temp (°F) | Daily Revenue ($) |
# |---|---|---|
# | 120 | 75 | 850 |
# | 90 | 60 | 620 |
# | 150 | 85 | 1100 |
# | 100 | 68 | 700 |

# %% [markdown]
# Answer:

# %% [markdown]
# 2. **City Demographics:**
#
# | City | Median Age | Avg Commute (min) | Park Acres per 1000 |
# |---|---|---|---|
# | Riverton | 34 | 22 | 3.2 |
# | Brookfield | 41 | 18 | 5.1 |
# | Lakeview | 29 | 27 | 2.0 |
# | Hilldale | 38 | 24 | 4.4 |

# %% [markdown]
# Answer:

# %% [markdown]
# 3. **Email Spam Filter:**
#
# | Number of Links | Contains 'Free' | Marked as Spam |
# |---|---|---|
# | 5 | Yes | Yes |
# | 0 | No | No |
# | 3 | Yes | Yes |
# | 1 | No | No |

# %% [markdown]
# Answer:

# %% [markdown]
# 4. **Marathon Training:**
#
# | Weekly Mileage | Long Run Distance (mi) | Finish Time (min) |
# |---|---|---|
# | 30 | 12 | 240 |
# | 45 | 18 | 210 |
# | 20 | 8 | 270 |
# | 55 | 20 | 195 |

# %% [markdown]
# Answer:

# %% [markdown]
# 5. **Streaming Service Catalog:**
#
# | Title | Genre | Release Year | Runtime (min) |
# |---|---|---|---|
# | Midnight Run | Thriller | 2019 | 118 |
# | Garden State Blues | Drama | 2021 | 104 |
# | Comet Tales | Sci-Fi | 2018 | 132 |
# | Laugh Track | Comedy | 2022 | 95 |

# %% [markdown]
# Answer:

# %% [markdown]
# 6. **Subscription Cancellation:**
#
# | Months Subscribed | Support Tickets Filed | Cancelled |
# |---|---|---|
# | 3 | 4 | Yes |
# | 18 | 0 | No |
# | 2 | 5 | Yes |
# | 24 | 1 | No |

# %% [markdown]
# Answer:

# %% [markdown]
# 7. **Crop Yield:**
#
# | Rainfall (in) | Fertilizer (lbs/acre) | Yield (bushels/acre) |
# |---|---|---|
# | 18 | 120 | 145 |
# | 25 | 150 | 175 |
# | 12 | 90 | 110 |
# | 30 | 180 | 200 |

# %% [markdown]
# Answer:

# %% [markdown]
# 8. **National Park Visits:**
#
# | Park | Avg Visitors/Month | Trail Miles | Annual Rainfall (in) |
# |---|---|---|---|
# | Cedar Ridge | 8200 | 45 | 38 |
# | Stone Hollow | 5400 | 30 | 22 |
# | Blue Pine | 12000 | 60 | 55 |
# | Red Canyon | 3100 | 25 | 10 |

# %% [markdown]
# Answer:

# %% [markdown]
# 9. **Job Applicant Screening:**
#
# | Years of Experience | Certification | Hired |
# |---|---|---|
# | 6 | Yes | Yes |
# | 1 | No | No |
# | 4 | Yes | Yes |
# | 2 | No | No |

# %% [markdown]
# Answer:

# %% [markdown]
# 10. **Online Ad Spend:**
#
# | Ad Spend ($) | Impressions (thousands) | Clicks |
# |---|---|---|
# | 500 | 40 | 320 |
# | 1200 | 95 | 780 |
# | 300 | 22 | 180 |
# | 900 | 70 | 600 |

# %% [markdown]
# Answer:

# %% [markdown]
# 11. **Coffee Bean Origins:**
#
# | Region | Altitude (m) | Acidity Score | Avg Price/lb ($) |
# |---|---|---|---|
# | Yirgacheffe | 1900 | 8.2 | 14.50 |
# | Huila | 1600 | 7.1 | 11.00 |
# | Sumatra Mandheling | 1300 | 5.5 | 12.25 |
# | Antigua | 1700 | 7.8 | 13.75 |

# %% [markdown]
# Answer:

# %% [markdown]
# 12. **Credit Card Fraud Detection:**
#
# | Transaction Amount ($) | Foreign Country | Flagged as Fraud |
# |---|---|---|
# | 1500 | Yes | Yes |
# | 40 | No | No |
# | 2200 | Yes | Yes |
# | 75 | No | No |

# %% [markdown]
# Answer:

# %% [markdown]
# 13. **Restaurant Wait Times:**
#
# | Party Size | Reservation Made | Wait Time (min) |
# |---|---|---|
# | 2 | No | 25 |
# | 4 | Yes | 5 |
# | 6 | No | 45 |
# | 3 | Yes | 10 |

# %% [markdown]
# Answer:

# %% [markdown]
# 14. **Music Festival Lineup:**
#
# | Artist | Genre | Set Length (min) | Stage |
# |---|---|---|---|
# | The Wandering Echoes | Indie Rock | 60 | Main |
# | DJ Solstice | Electronic | 90 | Dance Tent |
# | Mara Quinn | Folk | 45 | Acoustic |
# | Crimson Static | Punk | 40 | Side Stage |

# %% [markdown]
# Answer:

# %% [markdown]
# 15. **Hospital Readmission:**
#
# | Age | Chronic Condition | Readmitted within 30 Days |
# |---|---|---|
# | 68 | Yes | Yes |
# | 35 | No | No |
# | 72 | Yes | Yes |
# | 41 | No | No |

# %% [markdown]
# Answer:

# %% [markdown]
# 16. **Solar Panel Output:**
#
# | Panel Area (sq ft) | Sunlight Hours | Energy Output (kWh) |
# |---|---|---|
# | 100 | 6 | 18 |
# | 150 | 8 | 30 |
# | 80 | 4 | 10 |
# | 200 | 9 | 42 |

# %% [markdown]
# Answer:

# %% [markdown]
# 17. **Smartphone Models:**
#
# | Model | Screen Size (in) | Battery (mAh) | Storage (GB) |
# |---|---|---|---|
# | Nova X | 6.1 | 3500 | 128 |
# | Pixelite 5 | 6.5 | 4200 | 256 |
# | Quartz Mini | 5.4 | 3000 | 64 |
# | Vortex Pro | 6.7 | 4500 | 512 |

# %% [markdown]
# Answer:

# %% [markdown]
# 18. **Manufacturing Quality Control:**
#
# | Machine Vibration (Hz) | Operating Temp (°F) | Unit Passed Inspection |
# |---|---|---|
# | 12 | 180 | No |
# | 4 | 150 | Yes |
# | 15 | 195 | No |
# | 3 | 145 | Yes |

# %% [markdown]
# Answer:

# %% [markdown]
# 19. **Used Bicycle Pricing:**
#
# | Age (Years) | Mileage (mi) | Sale Price ($) |
# |---|---|---|
# | 1 | 200 | 650 |
# | 3 | 900 | 380 |
# | 5 | 1800 | 210 |
# | 2 | 500 | 520 |

# %% [markdown]
# Answer:

# %% [markdown]
# 20. **Library Branch Stats:**
#
# | Branch | Sq Footage | Books in Collection | Avg Daily Visitors |
# |---|---|---|---|
# | Downtown | 12000 | 85000 | 320 |
# | Westside | 6500 | 42000 | 150 |
# | Eastgate | 9000 | 61000 | 210 |
# | Northpark | 4800 | 30000 | 95 |

# %% [markdown]
# Answer:
