# %% [markdown]
# <a href="https://colab.research.google.com/github/gitmystuff/DTSC4050/blob/main/03-EDA/Your_Name_EDA_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA Assignment

# %% [markdown]
# Go through the following datasets and provide the shape of each dataset, the info, the first five rows, and simple descriptive statistics (if possible). Identify the Dependent Variable and then Train Test Split the data based on the dependent variable. Finally provide a correlation heat map (be sure you are using triu) of the features.
#
# ```
# # # generate a mask for the upper triangle
# # mask = np.zeros_like(corr, dtype=bool)
# # mask[np.triu_indices_from(mask)] = True
# ```

# %% [markdown]
# ## Forest Fires
#
# Forest Fires: This dataset models the area burned in forest fires based on meteorological and other variables.  Predicting the burned area (a continuous variable) from things like temperature, rainfall, wind speed, and the day of the week is a good linear regression exercise.

# %%
pip install ucimlrepo -q

# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd

# fetch dataset
forest_fires = fetch_ucirepo(id=162)

# metadata
print(forest_fires.metadata)

fires = pd.read_csv(forest_fires.metadata.data_url)

# %% [markdown]
# ## Wine Quality
#
# Wine Quality: Two datasets are included, related to red and white vinho verde wine samples, from the north of Portugal. The goal is to model wine quality based on physicochemical tests.

# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd

data = fetch_ucirepo(id=186)

# metadata
print(data.metadata)

wine = pd.read_csv(data.metadata.data_url)

# %% [markdown]
# ## Create a Synthetic Dataset with AI
#
# ### Generate a Scenario
#
# For example:
#
# **Coffee Shop Customer Satisfaction:**
#
# **Scenario:**  You own a coffee shop and want to understand the factors that influence customer satisfaction and spending.
#
# ### Generate a Dataset
#
# **Data Generation:**
# * **Customer Profiles:** Generate customers with attributes like age, income, coffee preference (strength, type), frequency of visits, and sensitivity to price.
# * **Shop Features:**  Create variables for things like ambiance (music, décor), Wi-Fi quality, waiting time, drink quality, and price.
# * **Satisfaction Score:**  Create a dependent variable that shows customer satisfaction. It can be discreet or continuous.
#
#
# ### Important Considerations for Synthetic Data
#
# * **Realism:**  Try to make your data as realistic as possible by considering real-world distributions and relationships between variables.
# * **Bias:** Be aware of potential biases you might introduce in your data generation process and try to mitigate them.
# * **Documentation:** Clearly document how you generated your data and any assumptions you made. This is crucial for reproducibility and interpretability.
